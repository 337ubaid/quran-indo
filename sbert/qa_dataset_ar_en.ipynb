# %%
from datasets import load_dataset
import pandas

dataset = load_dataset("nazimali/quran-question-answer-context")
dataset.shape
# Out:
# {'train': (1224, 28)}

# %%
dataset.set_format(type='pandas')

df = dataset['train'][:]
df.head()

# %%
df = df.drop(['question', 'answer', 'q_word', 'q_topic', 'fine_class', 'class', 'ontology_concept', 'ontology_concept2', 'source', 'chapter_name', 'context_missing_verses'], axis=1)
df.head()
# Out:
#    q_id  q_src_id quetion_type  chapter_no verse  \
# 0     1         1            F           2   1,2
# 1     2         2            F           2    25
# 2     3         3            F           2    28
# 3     4         4            F           2    29
# 4     5         5            D           2    31
#
#                                            answer_en   class_en fine_class_en  \
# 0  This is the Book of Allah (the Quran). The evi...     Entity     Holy Book
# 1  Yes, and the evidence: 'And give good news to ...  My Report        Yes-No
# 2  And you were dead, and He gave you life, then ...     Number        Number
# 3  He it is Who created for you all that is in th...     Number        Number
# 4  He taught Adam the names of all things, then H...     Entity          Term
#
#     ontology_concept2_en ontology_concept_en         q_topic_en q_word_en  \
# 0        The Noble Quran           The Quran           The book       Not
# 1          Her Qualities  Fruits of Paradise  Fruit of Paradise       Are
# 2     Man And His Nature               Death     Death and life  How Much
# 3  Facts In The Universe         The heavens            heavens        No
# 4                 I Know               Names              Nouns      What
#
#                                          question_en chapter_name_en  \
# 0  What is the only book that is free from any do...         The Cow
# 1  Are the fruits of paradise similar to the frui...         The Cow
# 2  How many deaths and how many lives do humans h...         The Cow
# 3                        How many heavens are there?         The Cow
# 4  What did Adam (peace be upon him) learn from A...         The Cow
#
#   verse_list                                            context  \
# 0     [1, 2]  Quran Surah 2 Ayah 1:\nAlif, Lam, Mim. (Only A...
# 1       [25]  Quran Surah 2 Ayah 25:\nAnd, (O Beloved Prophe...
# 2       [28]  Quran Surah 2 Ayah 28:\nHow Can You Deny Allah...
# 3       [29]  Quran Surah 2 Ayah 29:\nHe Is The One Who Crea...
# 4       [31]  Quran Surah 2 Ayah 31:\nAnd Allah Taught Adam ...
#
#                                         context_data
# 0  [{"index": 0, "q_src_id": 1, "surah": 2, "ayah...
# 1  [{"index": 1, "q_src_id": 2, "surah": 2, "ayah...
# 2  [{"index": 2, "q_src_id": 3, "surah": 2, "ayah...
# 3  [{"index": 3, "q_src_id": 4, "surah": 2, "ayah...
# 4  [{"index": 4, "q_src_id": 5, "surah": 2, "ayah...

# %%
from transformers import MarianMTModel, MarianTokenizer
import pandas as pd

# Load model English -> Indonesian
model_name = 'Helsinki-NLP/opus-mt-en-id'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Contoh data (ganti ini dengan dataset kamu)
df = pd.DataFrame({
    'text': ['Hello, how are you?', 'I love learning new things.', 'This is a test.']
})

# Fungsi translate
def translate(text):
    batch = tokenizer.prepare_seq2seq_batch([text], return_tensors="pt")
    translated = model.generate(**batch)
    return tokenizer.decode(translated[0], skip_special_tokens=True)

# Terapkan ke kolom tertentu
df['text_id'] = df['text'].apply(translate)

print(df)
